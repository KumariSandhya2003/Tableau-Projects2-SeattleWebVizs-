# %% [markdown]
# Web & Social Analytics - Final Project
#
#                         - Sandhya

# %%
# importing module(s) into namespace
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
pathname = 'C:/Users/email/Documents/'
pd.set_option('display.max_colwidth', 1500) # maximum column for getting all the text

# %%
import tweepy
from tweepy import OAuthHandler

#These keys will be different for everyone
consumer_key =  'EmP3ZLcBC75CDCLtn7BbyLi3m'
consumer_secret = 'aKrQyHLgNrJFAI3ycFq9qBCBYt92zclafpb3EM2TEJCFi6woOL'
access_token= '3453584954-mzTjUu9GmwX84MATzIxMTEfQKc5Xci0Ooyk6oKU'
access_secret= 'bcBBYpwx2GUdDNItzGYs8zKXwXGuFSH4cNIBMVHH6Vklc'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 


api = tweepy.API(auth)
user = api.me()
print (user.name)
# Out:
# Sandhya suman

# %%
# pull your tweets from your feed.  
for status in tweepy.Cursor(api.user_timeline).items(10):
    # Process a single status
    print(status.text)
# Out:
# @RockhurstU beautiful red tulips!
# Marketing strategies are still to go @RockhurstU BIA6303

# %%
# A SearchResults object isn't very helpful, how about a list
results = []

#Get the first 50 items based on the search query
for tweet in tweepy.Cursor(api.search, q='%23Honda',lang = "en").items(300):
    results.append(tweet)

# Verify the number of items returned
print(type(results))
print(len(results))
# Out:
# <class 'list'>
# 300

# %%
# Create a function to convert a given list of tweets into a Pandas DataFrame.
# The DataFrame will consist of only some values

import pandas as pd 

def toDataFrame(tweets):

    DataSet = pd.DataFrame()

   
    DataSet['tweetText'] = [tweet.text for tweet in tweets]
    DataSet['tweetRetweetCt'] = [tweet.retweet_count for tweet in tweets]
    DataSet['likes'] = [tweet.favorite_count for tweet in tweets]
    DataSet['tweetSource'] = [tweet.source for tweet in tweets]
    DataSet['date'] = [tweet.created_at for tweet in tweets]
    DataSet['len'] = [len(tweet.text) for tweet in tweets]
    DataSet['userName'] = [tweet.user.name for tweet in tweets]
    DataSet['userDesc'] = [tweet.user.description for tweet in tweets]
    DataSet['userFollowerCt'] = [tweet.user.followers_count for tweet in tweets]
    DataSet['userFriendsCt'] = [tweet.user.friends_count for tweet in tweets]
    DataSet['userLocation'] = [tweet.user.location for tweet in tweets]
    

    return DataSet

# %%
#let's use the function with our list
#Pass the tweets list to the above function to create a DataFrame
tweet_frame = toDataFrame(results)
print(tweet_frame.shape)
# Out:
# (300, 11)

# %%
tweet_frame['tweetText'][0:10]
# Out:
# 0                                                           【#SuperGT Rd.2 #富士スピードウェイ】\n#1 RAYBRIG NSX\n#honda #teamkunimitsu https://t.co/hdnMiiDfJz
# 1         Do you have a #HondaInsight? Do you need to replace your #headlight lightbulbs? Yo boi #XanderXero gots you!! Head… https://t.co/XPFHELfRDI
# 2             Keep your vehicle in its best shape this Spring! Schedule your service appointment with our technicians today!… https://t.co/HRyZTkobhn
# 3        Honda is progressing its 'Electric Vision' by confirming the name of its first fully electric urban vehicle – the ‘… https://t.co/xdRuHvfutc
# 4    Oh James..\n(Top Gear S15E02)\n.\n.\n#HistoryOfTopGear #TheGrandTour #JeremyClarkson #Clarkson #RichardHammond #Richard… https://t.co/X3P8LgVb4h
# 5                   @ToroRosso 🎵Oh! Lovesick－EikichiYazawa #矢沢永吉 \n☆Good Luck to #ToroRosso #Honda ♫#EikichiYazawa_channel 🙏\nhttps://t.co/150hxXEo0S
# 6        Two of Val’s happy customers! Congratulations Mrs. Delaney and Mr. Lee!! Thanks for choosing Ocean Honda of Weymout… https://t.co/TeieqRMURM
# 7        Cogratulations on your new Honda! Welcome to the Victory Honda Family! \n#VictoryHondaofSandusky #SanduskyOH #Honda… https://t.co/N7wDl0veC4
# 8             #CarHaiToCarghatKaro\nCarghat car cleaning delivery App\nDownload app now!\nprofessional doorstep car cleaning… https://t.co/13bEGxCzqd
# 9        Supermoto and 300 Series this weekend!\n\n#nyst #fast #speed #trackday #racetrack #ducati #kawasaki #suzuki #yamaha… https://t.co/jhvMDTaVxY
# Name: tweetText, dtype: object

# %%
tweet_frame.head()
# Exporting the data as csv file
#tweet_frame[0:300].to_csv('C:/Users/email/OneDrive/Documents/Sandhya/Web&Social Analytics/Honda3.csv', encoding='utf-8')

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
# Importing csv file
pathname ='C:/Users/email/OneDrive/Documents/Sandhya/Web&Social Analytics/'
tweetdf = pd.read_csv(pathname + "Honda3.csv", index_col = 0) 
print(tweetdf.shape)
print(list(tweetdf)) #columns of a data frame
print(tweetdf['tweetText'][:6])
# Out:
# (300, 11)
# ['tweetText', 'tweetRetweetCt', 'likes', 'tweetSource', 'date', 'len', 'userName', 'userDesc', 'userFollowerCt', 'userFriendsCt', 'userLocation']
# 0                                                           【#SuperGT Rd.2 #富士スピードウェイ】\n#1 RAYBRIG NSX\n#honda #teamkunimitsu https://t.co/hdnMiiDfJz
# 1         Do you have a #HondaInsight? Do you need to replace your #headlight lightbulbs? Yo boi #XanderXero gots you!! Head… https://t.co/XPFHELfRDI
# 2             Keep your vehicle in its best shape this Spring! Schedule your service appointment with our technicians today!… https://t.co/HRyZTkobhn
# 3        Honda is progressing its 'Electric Vision' by confirming the name of its first fully electric urban vehicle – the ‘… https://t.co/xdRuHvfutc
# 4    Oh James..\n(Top Gear S15E02)\n.\n.\n#HistoryOfTopGear #TheGrandTour #JeremyClarkson #Clarkson #RichardHammond #Richard… https://t.co/X3P8LgVb4h
# 5                   @ToroRosso 🎵Oh! Lovesick－EikichiYazawa #矢沢永吉 \n☆Good Luck to #ToroRosso #Honda ♫#EikichiYazawa_channel 🙏\nhttps://t.co/150hxXEo0S
# Name: tweetText, dtype: object

# %% [markdown]
# ## Exploratory Data Analysis :
# Starting with statistics and visuals of the data
# Next is Number of characters counted;Removal of Punctuation; Use of count vectorizer with different parameters to view top ten tokens, Added Customized stop words;
# Finally, sentiment analysis is performed using Affin dictionary provided in Text-Mining course.

# %%
# Number of Tweets
print('Total Number of extracted Tweets on Honda Twitter:', len(tweetdf))
#average length over all tweets:
print('Average Length over all tweets:', np.mean(tweetdf['len']))
# Total amount of likes 
print('Total Amount of Likes:', np.sum(tweetdf['likes']))
# maximum number of likes out of the tweets
print('Most Amount of Likes:', np.max(tweetdf['likes']))
# Total amount of retweets 
print('Total Amount of Retweets:', np.sum(tweetdf['tweetRetweetCt']))
# maximum number of the retweets
print('Most Amount of Retweets:', np.max(tweetdf['tweetRetweetCt']))
# Out:
# Total Number of extracted Tweets on Honda Twitter: 300
# Average Length over all tweets: 129.52
# Total Amount of Likes: 369
# Most Amount of Likes: 106
# Total Amount of Retweets: 739
# Most Amount of Retweets: 113

# %%
time_likes = pd.Series(data=tweetdf['likes'].values, index=tweetdf['date'])
time_likes.plot(figsize=(16, 4), color='g', label="likes", legend=True)
plt.title('Trends of Likes on Honda Twitter')
plt.xlabel('Dates')
plt.ylabel('# of Likes')
plt.show()

# %%
time_likes = pd.Series(data=tweetdf['tweetRetweetCt'].values, index=tweetdf['date'])
time_likes.plot(figsize=(16, 4), color='b', label="Retweets", legend=True)
plt.title('Trends of Retweets on Honda Twitter')
plt.xlabel('Dates')
plt.ylabel('# of Retweets')
plt.show()

# %%
time_likes = pd.Series(data=tweetdf['likes'].values, index=tweetdf['date'])
time_likes.plot(figsize=(16, 4), label="likes", legend=True)

time_retweets = pd.Series(data=tweetdf['tweetRetweetCt'].values, index=tweetdf['date'])
time_retweets.plot(figsize=(16, 4), label="retweets", legend=True)
plt.title('Correlation Between Likes and Retweets on Honda Twitter')
plt.xlabel('Dates')
plt.ylabel('# of Likes and Retweets')
plt.show()

# %% [markdown]
# #### Number of characters
# Let's check number of words in each tweet. The basic intuition behind this is that generally, the negative sentiments contain a lesser amount of words than the positive ones.

# %%
tweetdf['char_count'] = tweetdf['tweetText'].str.len() ## this also includes spaces
tweetdf[['tweetText','char_count']].head()
# Out:
#                                                                                                                                           tweetText  \
# 0                                                         【#SuperGT Rd.2 #富士スピードウェイ】\n#1 RAYBRIG NSX\n#honda #teamkunimitsu https://t.co/hdnMiiDfJz
# 1       Do you have a #HondaInsight? Do you need to replace your #headlight lightbulbs? Yo boi #XanderXero gots you!! Head… https://t.co/XPFHELfRDI
# 2           Keep your vehicle in its best shape this Spring! Schedule your service appointment with our technicians today!… https://t.co/HRyZTkobhn
# 3      Honda is progressing its 'Electric Vision' by confirming the name of its first fully electric urban vehicle – the ‘… https://t.co/xdRuHvfutc
# 4  Oh James..\n(Top Gear S15E02)\n.\n.\n#HistoryOfTopGear #TheGrandTour #JeremyClarkson #Clarkson #RichardHammond #Richard… https://t.co/X3P8LgVb4h
#
#    char_count
# 0          87
# 1         139
# 2         135
# 3         140
# 4         140

# %% [markdown]
# #### The next step is to remove punctuation, as it doesn’t add any extra information while treating text data.
# Therefore removing all instances of it will help us reduce the size of the tweet data.

# %%
# Removing punctuation

# https://stackoverflow.com/questions/8376691/how-to-remove-hashtag-user-link-of-a-tweet-using-regular-expression
# following code is borrowed from above link

import re,string
#('[^\w\s]','')
def strip_links(text):
    link_regex    =  re.compile('((https?):((//)|(\\\\))+([\w\d:#@%/;$()~_?\+-=\\\.&](#!)?)*)', re.DOTALL)
    links         = re.findall(link_regex, text)
    for link in links:
        text = text.replace(link[0], ', ')    
    return text

def strip_all_entities(text):
    entity_prefixes = ['@','#',""]
    for separator in  string.punctuation:
        if separator not in entity_prefixes :
            text = text.replace(separator,' ')
    words = []
    for word in text.split():
        word = word.strip()
        if word:
            if word[0] not in entity_prefixes:
                words.append(word)
    return ' '.join(words)

# %%
# applying the above function to tweetdf['tweetText] and keeping into tweetdf['punctuated']

tweetdf['tweetText'] = tweetdf['tweetText'].map(lambda x:strip_all_entities(strip_links(x))) 
print(tweetdf['tweetText'][0:6])
# Out:
# 0                                                                                            【#SuperGT Rd 2 RAYBRIG NSX
# 1                                            Do you have a Do you need to replace your lightbulbs Yo boi gots you Head…
# 2        Keep your vehicle in its best shape this Spring Schedule your service appointment with our technicians today …
# 3    Honda is progressing its Electric Vision by confirming the name of its first fully electric urban vehicle – the ‘…
# 4                                                                                              Oh James Top Gear S15E02
# 5                                                    🎵Oh Lovesick－EikichiYazawa ☆Good Luck to ♫#EikichiYazawa channel 🙏
# Name: tweetText, dtype: object

# %%
# Now removing apostrophe and quotation marks 
tweetdf['tweetText'] = tweetdf['tweetText'].str.replace('[^\w\s]','')
print(tweetdf['tweetText'][0:10])
# Out:
# 0                                                                                           SuperGT Rd 2 RAYBRIG NSX
# 1                                          Do you have a Do you need to replace your lightbulbs Yo boi gots you Head
# 2      Keep your vehicle in its best shape this Spring Schedule your service appointment with our technicians today
# 3    Honda is progressing its Electric Vision by confirming the name of its first fully electric urban vehicle  the
# 4                                                                                           Oh James Top Gear S15E02
# 5                                                       Oh LovesickEikichiYazawa Good Luck to EikichiYazawa channel
# 6      Two of Vals happy customers Congratulations Mrs Delaney and Mr Lee Thanks for choosing Ocean Honda of Weymout
# 7                                               Cogratulations on your new Honda Welcome to the Victory Honda Family
# 8                              Carghat car cleaning delivery App Download app now professional doorstep car cleaning
# 9                                                                              Supermoto and 300 Series this weekend
# Name: tweetText, dtype: object

# %% [markdown]
# ### Here's my cleaned data with less vocabulary clutter and the features produced in the end are more effective to analyze sentiments.

# %%
# let's see the changed data frame
print(tweetdf.shape)
print(list(tweetdf))
#tweetdf['cleanedText'] # appended the results into original data frame data frame
# Out:
# (300, 12)
# ['tweetText', 'tweetRetweetCt', 'likes', 'tweetSource', 'date', 'len', 'userName', 'userDesc', 'userFollowerCt', 'userFriendsCt', 'userLocation', 'char_count']

# %% [markdown]
# #### Now, moving towards Bag of Words - Vectorization.
# Bag of Words (BoW) refers to the representation of text which describes the presence of words within the text data. The intuition behind this is that two similar text fields will contain similar kind of words, and will therefore have a similar bag of words. Further, that from the text alone we can learn something about the meaning of the document.

# %%
# Instantiating the count vectorizer with all default parameter settings

# Default settings – binary= False, lowercase = True, stop_words = None, max_df =1.0, min_df = 1. 

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
cv = CountVectorizer(binary=False) 

#apply the transformation
cv_default = cv.fit_transform(tweetdf['tweetText']) # bag of words
print(cv_default.shape)

# "bag of words"
names = cv.get_feature_names()
count = np.sum(cv_default.toarray(), axis = 0) # add up feature counts 
count2 = count.tolist()  # convert numpy array to list
count_df = pd.DataFrame(count2, index = names, columns = ['count'])
# following line is getting top 10 features by count instead of alphabetical
count_df.sort_values(['count'], ascending = False)[0:10]  #arrange by count
# Out:
# (300, 1139)
#        count
# the      164
# to        95
# honda     89
# on        87
# rt        85
# of        68
# and       65
# for       62
# in        48
# is        45

# %% [markdown]
# As we can see the above output, feature space has 1096 features where highest occurring word is 'rt'-102,'the' - 68.
# 'the','to','is' 'for' words are stop words and not making any sense in our analysis. So we will remove these tokens.

# %%
# let's remove sklearn stop words
from sklearn.feature_extraction.text import CountVectorizer

# eliminating skl stop words 
cv1 = CountVectorizer(binary=False, stop_words = "english") 
cv1_skl_stopwords = cv1.fit_transform(tweetdf['tweetText']) # bag of words
print(cv1_skl_stopwords.shape)
names = cv1.get_feature_names()   #create list of feature names
count = np.sum(cv1_skl_stopwords.toarray(), axis = 0) # add up feature counts 
count2 = count.tolist()  # convert numpy array to list
# following line is creating a dataframe consist of count column
count_df = pd.DataFrame(count2, index = names, columns = ['count']) 
# following line is getting top 10 features by count instead of alphabetical
count_df.sort_values(['count'], ascending = False)[0:10]
# Out:
# (300, 994)
#           count
# honda        89
# rt           85
# new          42
# car          33
# 2019         30
# coming       19
# civic        18
# race         17
# electric     17
# today        16

# %%
# feature space
# top ten
count_df.sort_values(['count'], ascending = False)[:16]
# Out:
#                  count
# honda               89
# rt                  85
# new                 42
# car                 33
# 2019                30
# coming              19
# civic               18
# race                17
# electric            17
# today               16
# congratulations     16
# gt                  16
# taevision           14
# look                13
# blue                13
# saturday            13

# %% [markdown]
# #### We still see 'rt', therefore, adding a customized stop-word to remove it.

# %%
#creating a custom stop words list by adding a few terms to the nltk list
#creating a custom stop words list by adding a few terms to the nltk list
 #  import packages for excluding the stopwords
from sklearn.feature_extraction import text 
from nltk.corpus import stopwords
skl_stopwords = text.ENGLISH_STOP_WORDS

#creating an object using the default nltk stopwords
nltk_stopwords = stopwords.words("english") 
# Using sets to do intersections and unions
set_a = set(nltk_stopwords) 
set_b = set(skl_stopwords)
set_c = set(set_a).union(set_b)
remove_words = set(['rt','RT','amp']) 
my_stopwords = set_c.union(remove_words)

# Appending removed my_stopwords in the data frame
tweetdf['tweetText'] = tweetdf['tweetText'].apply(lambda x: " ".join(x for x in x.split() if x not in my_stopwords))
tweetdf['tweetText'][:6]
# Out:
# 0                                                         SuperGT Rd 2 RAYBRIG NSX
# 1                                   Do Do need replace lightbulbs Yo boi gots Head
# 2    Keep vehicle best shape Spring Schedule service appointment technicians today
# 3        Honda progressing Electric Vision confirming fully electric urban vehicle
# 4                                                         Oh James Top Gear S15E02
# 5                         Oh LovesickEikichiYazawa Good Luck EikichiYazawa channel
# Name: tweetText, dtype: object

# %%
# Now eliminaing customized stop words = my_stopwords
cv2 = CountVectorizer(binary=False, stop_words = my_stopwords) 

cv2_custom_stopwords = cv2.fit_transform(tweetdf['tweetText'])
print(cv2_custom_stopwords.shape)
names = cv2.get_feature_names()   #create list of feature names
count = np.sum(cv2_custom_stopwords.toarray(), axis = 0) # add up feature counts 
count2 = count.tolist()  # convert numpy array to list
# following line is creating a dataframe consist of count column
count_df = pd.DataFrame(count2, index = names, columns = ['count']) 
# following line is getting top 20 features by count instead of alphabetical
Top_25_words=count_df.sort_values(['count'], ascending = False)[:25]
# Out:
# (300, 986)

# %%
Top_25_words
# Exporting the top 20 words as csv file
#Top_25_words.to_csv('C:/Users/email/OneDrive/Documents/Sandhya/Web&Social Analytics/top25_Honda3.csv', encoding='utf-8')
# Out:
#                  count
# honda               89
# new                 42
# car                 33
# 2019                30
# coming              19
# civic               18
# race                17
# electric            17
# gt                  16
# congratulations     16
# today               16
# taevision           14
# look                13
# saturday            13
# blue                13
# board               12
# day                 12
# hours               12
# lets                12
# urban               12
# 08                  12
# 2020                10
# best                10
# schedule            10
# year                10

# %% [markdown]
# #### Let's check out the sentiments behind these tweets....

# %%
# Using afinn dictionaries to assign a value 
afinn = {}
for line in open('C:/Users/email/Downloads/'+"AFINN-111.txt"):
    tt = line.split('\t')
    afinn.update({tt[0]:int(tt[1])})


print(type(afinn), len(afinn))

for key, value in sorted(afinn.items())[0:10]:
    print(key + " => " + str(value))
print("~~~~~~~~~~~~")
for key, value in sorted(afinn.items())[2467:]:
    print(key + " => " + str(value))
# Out:
# <class 'dict'> 2477
# abandon => -2
# abandoned => -2
# abandons => -2
# abducted => -2
# abduction => -2
# abductions => -2
# abhor => -3
# abhorred => -3
# abhorrent => -3
# abhors => -3
# ~~~~~~~~~~~~
# yeah => 1
# yearning => 1
# yeees => 2
# yes => 1
# youthful => 2
# yucky => -2
# yummy => 3
# zealot => -2
# zealots => -2
# zealous => 2

# %%
# here we are going for strictly the sum:  add up the positives and "subtract" the negatives
# returning a label

def afinn_sent(inputstring):
    
    sentcount =0
    for word in inputstring.split():  
        if word.rstrip('?:!.,;') in afinn:
            sentcount = sentcount + afinn[word.rstrip('?:!.,;')]
            
    
    if (sentcount < 0):
        sentiment = 'Negative'
    elif (sentcount >0):
        sentiment = 'Positive'
    else:
        sentiment = 'Neutral'
    
    return sentiment

# %%
tweetdf['sentiments'] = tweetdf.tweetText.apply(lambda x: afinn_sent(x))
print(type(tweetdf.tweetText))
# Out:
# <class 'pandas.core.series.Series'>

# %%
tweetdf.iloc[0:5][['tweetText','sentiments']]
# Out:
#                                                                        tweetText  \
# 0                                                       SuperGT Rd 2 RAYBRIG NSX
# 1                                 Do Do need replace lightbulbs Yo boi gots Head
# 2  Keep vehicle best shape Spring Schedule service appointment technicians today
# 3      Honda progressing Electric Vision confirming fully electric urban vehicle
# 4                                                       Oh James Top Gear S15E02
#
#   sentiments
# 0    Neutral
# 1    Neutral
# 2   Positive
# 3    Neutral
# 4    Neutral

# %%
tweetdf.iloc[:10][['tweetText','tweetRetweetCt',  'likes', 'tweetSource','sentiments']]
#tweetdf[:10]
# Exporting the data as csv file
#tweetdf[0:300].to_csv('C:/Users/email/OneDrive/Documents/Sandhya/Web&Social Analytics/Honda3Sent.csv', encoding='utf-8')
# Out:
#                                                                                          tweetText  \
# 0                                                                         SuperGT Rd 2 RAYBRIG NSX
# 1                                                   Do Do need replace lightbulbs Yo boi gots Head
# 2                    Keep vehicle best shape Spring Schedule service appointment technicians today
# 3                        Honda progressing Electric Vision confirming fully electric urban vehicle
# 4                                                                         Oh James Top Gear S15E02
# 5                                         Oh LovesickEikichiYazawa Good Luck EikichiYazawa channel
# 6  Two Vals happy customers Congratulations Mrs Delaney Mr Lee Thanks choosing Ocean Honda Weymout
# 7                                            Cogratulations new Honda Welcome Victory Honda Family
# 8                Carghat car cleaning delivery App Download app professional doorstep car cleaning
# 9                                                                     Supermoto 300 Series weekend
#
#    tweetRetweetCt  likes          tweetSource sentiments
# 0               0      0   Twitter Web Client    Neutral
# 1               0      0  Twitter for Android    Neutral
# 2               0      0        Sprout Social   Positive
# 3               0      0      Twitter Web App    Neutral
# 4               0      0            Instagram    Neutral
# 5               0      0      Twitter Web App    Neutral
# 6               0      0            TweetDeck   Positive
# 7               0      0            TweetDeck    Neutral
# 8               0      0       Hootsuite Inc.    Neutral
# 9               0      0                IFTTT    Neutral

# %%
#set.seed(1234)
from wordcloud import WordCloud,STOPWORDS
all_words = ' '.join([text for text in tweetdf['tweetText']])

wordcloud = WordCloud(width=800, height=500, random_state=21,
            max_font_size=110,contour_color= 'black',mode='RGB',background_color='white',collocations=False).generate(all_words)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# ### Words that appear darker indicate higher average Engagement

# %% [markdown]
#                                     -----------  The End  --------------
